# %%
import numpy as np
import pandas as pd
df=pd.read_csv('raw_messy_dataset.csv')
df
# Out:
#         Name      Age Gender              Email     Join_Date Salary  \
# 0      Alice      NaN    NaN  user0@example.com    2021-05-21    NaN
# 1        Bob       40      M  user1@example.com           NaN  50000
# 2    Charlie  unknown   Male  user2@example.com    2020/01/01  50000
# 3      David      NaN    NaN  user3@example.com    2021-05-21  70000
# 4        Eva       35  Other  user4@example.com  July 4, 2020  70000
# ..       ...      ...    ...                ...           ...    ...
# 100    Alice      NaN    NaN  user0@example.com    2021-05-21    NaN
# 101      Bob       40      M  user1@example.com           NaN  50000
# 102  Charlie  unknown   Male  user2@example.com    2020/01/01  50000
# 103    David      NaN    NaN  user3@example.com    2021-05-21  70000
# 104      Eva       35  Other  user4@example.com  July 4, 2020  70000
#
#       Department
# 0          Admin
# 1    Engineering
# 2             HR
# 3          Admin
# 4    Engineering
# ..           ...
# 100        Admin
# 101  Engineering
# 102           HR
# 103        Admin
# 104  Engineering
#
# [105 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        105 non-null    object
#  1   Age         72 non-null     object
#  2   Gender      89 non-null     object
#  3   Email       95 non-null     object
#  4   Join_Date   70 non-null     object
#  5   Salary      78 non-null     object
#  6   Department  89 non-null     object
# dtypes: object(7)
# memory usage: 5.9+ KB

# %%
df.tail()
# Out:
#         Name      Age Gender              Email     Join_Date Salary  \
# 100    Alice      NaN    NaN  user0@example.com    2021-05-21    NaN
# 101      Bob       40      M  user1@example.com           NaN  50000
# 102  Charlie  unknown   Male  user2@example.com    2020/01/01  50000
# 103    David      NaN    NaN  user3@example.com    2021-05-21  70000
# 104      Eva       35  Other  user4@example.com  July 4, 2020  70000
#
#       Department
# 100        Admin
# 101  Engineering
# 102           HR
# 103        Admin
# 104  Engineering

# %%
df.head()
# Out:
#       Name      Age Gender              Email     Join_Date Salary  \
# 0    Alice      NaN    NaN  user0@example.com    2021-05-21    NaN
# 1      Bob       40      M  user1@example.com           NaN  50000
# 2  Charlie  unknown   Male  user2@example.com    2020/01/01  50000
# 3    David      NaN    NaN  user3@example.com    2021-05-21  70000
# 4      Eva       35  Other  user4@example.com  July 4, 2020  70000
#
#     Department
# 0        Admin
# 1  Engineering
# 2           HR
# 3        Admin
# 4  Engineering

# %%
df.describe()
# Out:
#          Name Age Gender              Email   Join_Date Salary   Department
# count     105  72     89                 95          70     78           89
# unique     10   5      5                 90           4      5            5
# top     Alice  40   Male  user0@example.com  2021-05-21  50000  Engineering
# freq       11  22     22                  2          26     22           26

# %%
#replace the 
df['Age']=df['Age'].replace('unknown',np.NaN)
df
# Out:
#         Name  Age Gender              Email     Join_Date Salary   Department
# 0      Alice  NaN    NaN  user0@example.com    2021-05-21    NaN        Admin
# 1        Bob   40      M  user1@example.com           NaN  50000  Engineering
# 2    Charlie  NaN   Male  user2@example.com    2020/01/01  50000           HR
# 3      David  NaN    NaN  user3@example.com    2021-05-21  70000        Admin
# 4        Eva   35  Other  user4@example.com  July 4, 2020  70000  Engineering
# ..       ...  ...    ...                ...           ...    ...          ...
# 100    Alice  NaN    NaN  user0@example.com    2021-05-21    NaN        Admin
# 101      Bob   40      M  user1@example.com           NaN  50000  Engineering
# 102  Charlie  NaN   Male  user2@example.com    2020/01/01  50000           HR
# 103    David  NaN    NaN  user3@example.com    2021-05-21  70000        Admin
# 104      Eva   35  Other  user4@example.com  July 4, 2020  70000  Engineering
#
# [105 rows x 7 columns]

# %%
#converted the column to numeric
df['Age'] = pd.to_numeric(df['Age'], errors = 'coerce')
df.head()
# Out:
#       Name   Age Gender              Email     Join_Date Salary   Department
# 0    Alice   NaN    NaN  user0@example.com    2021-05-21    NaN        Admin
# 1      Bob  40.0      M  user1@example.com           NaN  50000  Engineering
# 2  Charlie   NaN   Male  user2@example.com    2020/01/01  50000           HR
# 3    David   NaN    NaN  user3@example.com    2021-05-21  70000        Admin
# 4      Eva  35.0  Other  user4@example.com  July 4, 2020  70000  Engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        105 non-null    object
#  1   Age         59 non-null     float64
#  2   Gender      89 non-null     object
#  3   Email       95 non-null     object
#  4   Join_Date   70 non-null     object
#  5   Salary      78 non-null     object
#  6   Department  89 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.9+ KB

# %%
#checked unique values
df['Gender'].unique()
# Out:
# array([nan, 'M', 'Male', 'Other', 'Female', 'F'], dtype=object)

# %%
#convert to standard form
df['Gender'] = df['Gender'].replace({'M':'Male',
                                      'F': 'Female'})
df
# Out:
#         Name   Age Gender              Email     Join_Date Salary   Department
# 0      Alice   NaN    NaN  user0@example.com    2021-05-21    NaN        Admin
# 1        Bob  40.0   Male  user1@example.com           NaN  50000  Engineering
# 2    Charlie   NaN   Male  user2@example.com    2020/01/01  50000           HR
# 3      David   NaN    NaN  user3@example.com    2021-05-21  70000        Admin
# 4        Eva  35.0  Other  user4@example.com  July 4, 2020  70000  Engineering
# ..       ...   ...    ...                ...           ...    ...          ...
# 100    Alice   NaN    NaN  user0@example.com    2021-05-21    NaN        Admin
# 101      Bob  40.0   Male  user1@example.com           NaN  50000  Engineering
# 102  Charlie   NaN   Male  user2@example.com    2020/01/01  50000           HR
# 103    David   NaN    NaN  user3@example.com    2021-05-21  70000        Admin
# 104      Eva  35.0  Other  user4@example.com  July 4, 2020  70000  Engineering
#
# [105 rows x 7 columns]

# %%
# convert date column to date format
df['Join_Date'] = pd.to_datetime(df['Join_Date'], errors = 'coerce')
df
# Out:
#         Name   Age Gender              Email  Join_Date Salary   Department
# 0      Alice   NaN    NaN  user0@example.com 2021-05-21    NaN        Admin
# 1        Bob  40.0   Male  user1@example.com        NaT  50000  Engineering
# 2    Charlie   NaN   Male  user2@example.com        NaT  50000           HR
# 3      David   NaN    NaN  user3@example.com 2021-05-21  70000        Admin
# 4        Eva  35.0  Other  user4@example.com        NaT  70000  Engineering
# ..       ...   ...    ...                ...        ...    ...          ...
# 100    Alice   NaN    NaN  user0@example.com 2021-05-21    NaN        Admin
# 101      Bob  40.0   Male  user1@example.com        NaT  50000  Engineering
# 102  Charlie   NaN   Male  user2@example.com        NaT  50000           HR
# 103    David   NaN    NaN  user3@example.com 2021-05-21  70000        Admin
# 104      Eva  35.0  Other  user4@example.com        NaT  70000  Engineering
#
# [105 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        105 non-null    object
#  1   Age         59 non-null     float64
#  2   Gender      89 non-null     object
#  3   Email       95 non-null     object
#  4   Join_Date   26 non-null     datetime64[ns]
#  5   Salary      78 non-null     object
#  6   Department  89 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 5.9+ KB

# %%
#convert salary column to numeric 
df['Salary'] = pd.to_numeric(df['Salary'], errors = 'coerce')
df['Salary'].head()
# Out:
# 0        NaN
# 1    50000.0
# 2    50000.0
# 3    70000.0
# 4    70000.0
# Name: Salary, dtype: float64

# %%
#to check null or missing values
df.isnull().sum()
# Out:
# Name           0
# Age           46
# Gender        16
# Email         10
# Join_Date     79
# Salary        41
# Department    16
# dtype: int64

# %%
#to fill values
df['Age'].fillna(df['Age'].median(), inplace = Truei
df['Age'].head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14228\1412781466.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace = True)
# 0    35.0
# 1    40.0
# 2    35.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
#filled null or blank values by Unknown keyword
df['Gender'].fillna ('Unknown' ,  inplace = True)
df['Gender'].head(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14228\3247606323.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna ('Unknown' ,  inplace = True)
# 0    Unknown
# 1       Male
# 2       Male
# 3    Unknown
# 4      Other
# 5      Other
# 6     Female
# 7      Other
# 8     Female
# 9       Male
# Name: Gender, dtype: object

# %%
#to fill values
df['Salary'].fillna(df['Salary'].mean(), inplace = True)
df['Salary'].head(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14228\1059264496.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].mean(), inplace = True)
# 0    64687.5
# 1    50000.0
# 2    50000.0
# 3    70000.0
# 4    70000.0
# 5    70000.0
# 6    80000.0
# 7    64687.5
# 8    50000.0
# 9    80000.0
# Name: Salary, dtype: float64

# %%
#filled null or blank values by Unknown keyword
df['Department'].fillna ('Unknown' ,  inplace = True)
df['Department'].head(20)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14228\683524575.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Department'].fillna ('Unknown' ,  inplace = True)
# 0           Admin
# 1     Engineering
# 2              HR
# 3           Admin
# 4     Engineering
# 5           Admin
# 6     Engineering
# 7              HR
# 8     Engineering
# 9     Engineering
# 10    Engineering
# 11          Sales
# 12          Sales
# 13          Sales
# 14             HR
# 15          Admin
# 16        Unknown
# 17    Engineering
# 18    Engineering
# 19             HR
# Name: Department, dtype: object

# %%
#filled null or blank values by specific email
df['Email'].fillna ('iGAP@1234' ,  inplace = True)
df['Email'].tail(20)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14228\1181334648.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Email'].fillna ('iGAP@1234' ,  inplace = True)
# 85     user85@example.com
# 86     user86@example.com
# 87     user87@example.com
# 88     user88@example.com
# 89     user89@example.com
# 90              iGAP@1234
# 91              iGAP@1234
# 92              iGAP@1234
# 93              iGAP@1234
# 94              iGAP@1234
# 95              iGAP@1234
# 96              iGAP@1234
# 97              iGAP@1234
# 98              iGAP@1234
# 99              iGAP@1234
# 100     user0@example.com
# 101     user1@example.com
# 102     user2@example.com
# 103     user3@example.com
# 104     user4@example.com
# Name: Email, dtype: object

# %%
#checked duplicate values
df.duplicated().unique()
# Out:
# array([False,  True])

# %%
#drop duplicate values
df.drop_duplicates(inplace = True)
df
# Out:
#        Name   Age   Gender              Email  Join_Date   Salary   Department
# 0     Alice  35.0  Unknown  user0@example.com 2021-05-21  64687.5        Admin
# 1       Bob  40.0     Male  user1@example.com        NaT  50000.0  Engineering
# 2   Charlie  35.0     Male  user2@example.com        NaT  50000.0           HR
# 3     David  35.0  Unknown  user3@example.com 2021-05-21  70000.0        Admin
# 4       Eva  35.0    Other  user4@example.com        NaT  70000.0  Engineering
# ..      ...   ...      ...                ...        ...      ...          ...
# 95    Frank  35.0     Male          iGAP@1234        NaT  50000.0      Unknown
# 96    Grace  40.0     Male          iGAP@1234        NaT  70000.0        Sales
# 97   Hannah  35.0     Male          iGAP@1234        NaT  60000.0      Unknown
# 98      Ivy  35.0   Female          iGAP@1234        NaT  50000.0      Unknown
# 99     Jack  35.0  Unknown          iGAP@1234        NaT  60000.0        Admin
#
# [100 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        100 non-null    object
#  1   Age         100 non-null    float64
#  2   Gender      100 non-null    object
#  3   Email       100 non-null    object
#  4   Join_Date   24 non-null     datetime64[ns]
#  5   Salary      100 non-null    float64
#  6   Department  100 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 6.2+ KB

# %%
df.to_csv('Cleaned_dataset.csv')
